# %%
f = open('input.dat')
lines = f.readlines()
lines = [line.strip() for line in lines if line.strip()]
f.close()
import numpy as np
import re

dirmap = {'R':[0,1], 'L':[0,-1], 'U':[-1,0], 'D':[1,0]}

direction, holes, color = [], [], []
for line in lines:
    a, b, c = line.split()
    direction.append(a)
    holes.append(int(b))
    color.append(c)

sizex = 0
sizey = 0
maxx = -1e12
maxy = -1e12
for d, h, c in zip(direction, holes, color):
    dy, dx = dirmap[d]
    sizex += abs(dx*h)
    sizey += abs(dy*h)

excavation = [[['.', None, 'O'] for _ in range(sizex)] for _ in range(sizey)]
current = np.abs([sizey//2-1, sizex//2-1])

for d, h, c in zip(direction, holes, color):
    dy, dx = dirmap[d]
    for _ in range(abs(dx)*h):
        current = current + [0,dx]
        excavation[current[0]][current[1]] = ['#', c, d]
    for _ in range(abs(dy)*h):

        excavation[current[0]][current[1]][2] = d
        current = current + [dy,0]
        excavation[current[0]][current[1]] = ['#', c, d]

ret = 0
tmp = []
minx = 1e12
maxx = -1e12
for exc in excavation:
    exc_l = np.array(exc)
    exc_m = list(exc_l[:,0])
    exc_l = list(exc_l[:,2])
    if '#' not in exc_m: continue
    exc_m = ''.join(exc_m)
    exc_m = re.sub('^\.+', '', exc_m)
    exc_m = re.sub('\.+$', '', exc_m)

    exc_l = ''.join(exc_l)
    exc_l = re.sub('^O+', '', exc_l)
    exc_l = re.sub('O+$', '', exc_l)
    tmp.append([exc_m,exc_l])

excavation = [[c for c in val[0]] for val in tmp]
excavation_dir = [[c for c in val[1]] for val in tmp]
ret = 0
# excavation_dir = [
# 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'D', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U', 'L', 'L', 'D', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'
# ]
# excavation_dir = [
# ['U', 'R', 'R', 'R', 'R', 'R', 'D',], 
# ['U', 'O', 'O', 'O', 'O', 'O', 'D',], 
# ['U', 'O', 'D', 'L', 'U', 'O', 'D',], 
# ['U', 'O', 'D', 'O', 'U', 'O', 'D',], 
# ['U', 'L', 'D', 'O', 'U', 'O', 'D',], 
# ['U', 'R', 'D', 'O', 'U', 'D', 'D',], 
# ['U', 'O', 'O', 'O', 'O', 'D', 'O',], 
# ['U', 'U', 'O', 'O', 'O', 'D', 'D',], 
# ['O', 'U', 'O', 'O', 'O', 'O', 'D',], 
# ['O', 'U', 'L', 'L', 'L', 'L', 'D']
# ]
for exc, c in zip(excavation, excavation_dir):
    integrating=False
    valline = 0
    for i, v in enumerate(c):
        if integrating:
            valline+=1
        if v == 'U' and integrating is False:
            integrating=True
            valline+=1
        elif v == 'D':
            if i == len(c)-1:
                pass
            elif c[i+1] == 'O':
                integrating=False
    # print(c, valline) 
    ret+=valline

            
    
    # print(contained, len(contained))

print(ret)
# Out:
# 47527

# %%
f = open('input.dat')
lines = f.readlines()
lines = [line.strip() for line in lines if line.strip()]
f.close()
import numpy as np
import re

from tqdm import tqdm

dirmap = {'0':'R', '2':'L', '3':'U', '1':'D'}
dirmap_2 = {'0':[0,1], '2':[0,-1], '3':[-1,0], '1':[1,0]}

direction, holes = [], []
direction_w = []
for line in lines:
    _, _, c = line.split()
    c = c.strip('(#)')
    holes.append(int('0x'+c[:5], 16))
    direction.append(dirmap_2[c[-1]])
    direction_w.append(dirmap[c[-1]])

h_moves = []
v_moves = []
hmove = 0
vmove = 0
idx_start = direction_w.index('U')
tmp1 = direction[idx_start:]
tmp2 = direction[:idx_start]
direction = tmp1.append(tmp2)
print(direction)

# Used to define rotation direction, clockwise
# for i, (d, h) in enumerate(zip(tqdm(direction), holes)):
#     if d[0] == 0:
#         hmove+=d[1]*h
#         if i > 0:
#             if direction[i-1][0] == 0:
#                 assert False
#     else:
#         vmove+=d[0]*h
#         if i > 0:
#             if direction[i-1][1] == 0:
#                 assert False
#     h_moves.append(hmove)
#     v_moves.append(vmove)
# rotat = {}
# minmax = [np.argmax(h_moves), np.argmin(h_moves), np.argmax(v_moves), np.argmin(v_moves)]
# minmaxd = ['R', 'L', 'D', 'U']
# minmax, minmaxd = zip(*sorted(zip(minmax, minmaxd)))
# print(minmax, minmaxd)
# print('max', np.argmax(h_moves), 'min', np.argmin(h_moves))
# print('max', np.argmax(v_moves), 'min', np.argmin(v_moves))
# Out:
# None

# %%
sizex = 0
sizey = 0
maxx = -1e12
maxy = -1e12
for d, h, c in zip(direction, holes, color):
    dy, dx = dirmap[d]
    sizex += abs(dx*h)
    sizey += abs(dy*h)

excavation = [[['.', None, 'O'] for _ in range(sizex)] for _ in range(sizey)]
current = np.abs([sizey//2-1, sizex//2-1])

for d, h, c in zip(direction, holes, color):
    dy, dx = dirmap[d]
    for _ in range(abs(dx)*h):
        current = current + [0,dx]
        excavation[current[0]][current[1]] = ['#', c, d]
    for _ in range(abs(dy)*h):

        excavation[current[0]][current[1]][2] = d
        current = current + [dy,0]
        excavation[current[0]][current[1]] = ['#', c, d]

ret = 0
tmp = []
minx = 1e12
maxx = -1e12
for exc in excavation:
    exc_l = np.array(exc)
    exc_m = list(exc_l[:,0])
    exc_l = list(exc_l[:,2])
    if '#' not in exc_m: continue
    exc_m = ''.join(exc_m)
    exc_m = re.sub('^\.+', '', exc_m)
    exc_m = re.sub('\.+$', '', exc_m)

    exc_l = ''.join(exc_l)
    exc_l = re.sub('^O+', '', exc_l)
    exc_l = re.sub('O+$', '', exc_l)
    tmp.append([exc_m,exc_l])

excavation = [[c for c in val[0]] for val in tmp]
excavation_dir = [[c for c in val[1]] for val in tmp]
ret = 0
# excavation_dir = [
# 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'D', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U', 'L', 'L', 'D', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'
# ]
# excavation_dir = [
# ['U', 'R', 'R', 'R', 'R', 'R', 'D',], 
# ['U', 'O', 'O', 'O', 'O', 'O', 'D',], 
# ['U', 'O', 'D', 'L', 'U', 'O', 'D',], 
# ['U', 'O', 'D', 'O', 'U', 'O', 'D',], 
# ['U', 'L', 'D', 'O', 'U', 'O', 'D',], 
# ['U', 'R', 'D', 'O', 'U', 'D', 'D',], 
# ['U', 'O', 'O', 'O', 'O', 'D', 'O',], 
# ['U', 'U', 'O', 'O', 'O', 'D', 'D',], 
# ['O', 'U', 'O', 'O', 'O', 'O', 'D',], 
# ['O', 'U', 'L', 'L', 'L', 'L', 'D']
# ]
for exc, c in zip(excavation, excavation_dir):
    integrating=False
    valline = 0
    for i, v in enumerate(c):
        if integrating:
            valline+=1
        if v == 'U' and integrating is False:
            integrating=True
            valline+=1
        elif v == 'D':
            if i == len(c)-1:
                pass
            elif c[i+1] == 'O':
                integrating=False
    # print(c, valline) 
    ret+=valline

            
    
    # print(contained, len(contained))

print(ret)
